# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel ')
r.text
# Out:
# '{"RealtimeWaterLevel_OPENDATA":[\r\n{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H001","WaterLevel":"684.96"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H002","WaterLevel":"531.13"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H041","WaterLevel":"830.59"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H043","WaterLevel":"440.87"}\r\n,{"RecordTime":"2021-08-19T23:10:00","StationIdentifier":"1140H048","WaterLevel":"29.01"}\r\n,{"RecordTime":"2021-08-19T23:10:00","StationIdentifier":"1140H049","WaterLevel":"22.29"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H054","WaterLevel":"247.39"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H058","WaterLevel":"4.36"}\r\n,{"RecordTime":"2021-08-19T23:10:00","StationIdentifier":"1140H066","WaterLevel":"2.99"}\r\n,{"RecordTime":"2021-08-19T23:10:00","StationIdentifier":"1140H067","WaterLevel":"32.21"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H068","WaterLevel":"49.42"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H076","WaterLevel":"137.64"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H082","WaterLevel":"7.31"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H089","WaterLevel":"0.00"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H095","WaterLevel":"110.42"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H096","WaterLevel":"170.58"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H097","WaterLevel":"172.30"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H098","WaterLevel":"175.14"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H099","WaterLevel":"263.53"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H101","WaterLevel":"181.97"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H102","WaterLevel":"209.09"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H105","WaterLevel":"2.22"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H106","WaterLevel":"49.14"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H107","WaterLevel":"4.43"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H108","WaterLevel":"12.48"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H109","WaterLevel":"49.43"}\r\n,{"RecordTime":"2021-08-19T23:10:00","StationIdentifier":"1140H110","WaterLevel":"42.43"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H126","WaterLevel":"82.66"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H127","WaterLevel":"33.45"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H128","WaterLevel":"19.91"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1140H129","WaterLevel":"28.17"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1270H001","WaterLevel":"22.49"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1280H001","WaterLevel":"71.56"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1290H002","WaterLevel":"41.48"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1290H004","WaterLevel":"115.99"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1290H006","WaterLevel":"66.54"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1290H007","WaterLevel":"13.75"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1300H013","WaterLevel":"247.80"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1300H014","WaterLevel":"209.47"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1300H016","WaterLevel":"100.77"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1300H017","WaterLevel":"27.56"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationIdentifier":"1300H018","WaterLevel":"97.61"}\r\n,{"RecordTime":"2021-08-19T23:20:00","StationId ...

# %%
import json
json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-2e3f9756c5a6> in <module>
#       1 import json
# ----> 2 json.loads(r.text)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
